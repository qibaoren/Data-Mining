# %% [markdown]
# # Confusion Matrix
# ![Matrix.jpg](attachment:Matrix.jpg)

# %% [markdown]
# # Main Metrics
# |Metric|Formula|Interpretation|
# |:----:|:-----:|:------------:|
# |Precision|${TP}\over{TP+FP}$|分类后的正样本纯度|
# |Recall|${TP}\over{TP+FN}$|正样本的分类成功率|
# |Specificity|${TN}\over{TN+FP}$|负样本的分类成功率|
# |F1|$${2TP}\over{2TP+FP+FN}$$|Precision和Recall的调和中项|
# |Accuracy|$${TP+TN}\over{TP+FP+FN+TN}$$|样本分类成功率|

# %% [markdown]
# # F1可视化

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator
import numpy as np

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.set_title("F1")
plt.figure(figsize=(6,6), dpi=600) 
Precision = np.linspace(0, 1, num=201, endpoint=True)
Recall = np.linspace(0, 1, num=201, endpoint=True)
X, Y = np.meshgrid(Precision, Recall)
F = (2 * X * Y ) / (X + Y)
surf = ax.plot_surface(X, Y, F, cmap=plt.cm.autumn,
                       linewidth=0, antialiased=False)
ax.set_zlim(0, 1)
ax.invert_xaxis()
ax.set_xlabel("Precision")
ax.set_ylabel("Recall")
fig.colorbar(surf, shrink=0.5, aspect=5)
plt.show()
# Out:
# C:\Users\Qi\AppData\Local\Temp\ipykernel_14248\1454307653.py:12: RuntimeWarning: invalid value encountered in true_divide
#   F = (2 * X * Y ) / (X + Y)

# %% [markdown]
# # ROC

# %% [markdown]
# * ROC是在不同的Threshold values条件下，以Recall作为纵坐标，FPR作为横坐标的曲线
#
# |Axis|Metric|Formula|Interpretation|
# |::|:----:|:-----:|:------------:|
# |Y|Recall|${TP}\over{TP+FN}$|正样本的分类成功率|
# |X|FPR|${FP}\over{FP+TN}$|负样本的分类失败率|
#
# * TP+FN是定值
# * FP+TN是定值
# * TP与FP会因为不同选取的Threshold values而变化

# %% [markdown]
# # AUC

# %% [markdown]
# ROC曲线下的面积叫做AUC
# ![AUC.jpg](attachment:AUC.jpg)
